# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# !python learn.py --dataset WN18RR --model BiQUE --rank 500 \
#         --optimizer Adagrad --learning_rate 1e-1 --batch_size 300 \
#         --regularizer N3 --reg 1.5e-1 --max_epochs 100 --valid 5 -train -id 0 -save -weight
# Out:
# (86835, 3)
# (40943, 22, 40943)
# Epoch: 1
# train loss:   0%|                                    | 0/173670 [00:00<?, ?ex/s]
# Traceback (most recent call last):
#   File "learn.py", line 121, in <module>
#     cur_loss = optimizer.epoch(examples, e=e, weight=ce_weight)
#   File "/root/Chi/BiOCT/codes/optimizers.py", line 32, in epoch
#     predictions, factors = self.model.forward(input_batch)
#   File "/root/Chi/BiOCT/codes/models.py", line 77, in forward
#     return  res @ torch.cat([projection_transH_pytorch(self.h1.weight.transpose(0, 1), rel1[:, self.rank * 8:].weight.transpose(0, 1)), projection_transH_pytorch(self.h2.weight.transpose(0, 1), rel2[:, self.rank * 8:].weight.transpose(0, 1))], 0), [(get_norm(head1, head2, 8), get_norm(rel1[:, :self.rank*8], rel2[:, :self.rank*8], 8), get_norm(tail1, tail2, 8))]
# AttributeError: 'Tensor' object has no attribute 'weight'

# %%
# !python learn.py --dataset FB237 --model BiQUE --rank 500 \
        --optimizer Adagrad --learning_rate 1e-1 --batch_size 500 \
        --regularizer N3 --reg 0.0 --max_epochs 200 --valid 5 -train -id 0 -save #7e-2
# Out:
# (272115, 3)
# (14541, 474, 14541)
# Epoch: 1
# train loss: 100%|█| 544230/544230 [00:51<00:00, 10644.46ex/s, loss=5.2, reg=0.9]
# Epoch: 2
# train loss:  92%|▉| 499000/544230 [00:46<00:04, 10733.14ex/s, loss=4.7, reg=0.7]

# %%
# !python learn.py --dataset YAGO3-10 --model BiQUE --rank 128 \
#         --optimizer Adagrad --learning_rate 1e-1 --batch_size 1000 \
#         --regularizer N3 --reg 5e-3 --max_epochs 200 --valid 5 -train -id 0 -save

# %%
# !python learn.py --dataset Concept100k --model BiQUE --rank 500 \
#         --optimizer Adagrad --learning_rate 1e-1 --batch_size 5000 \
#         --regularizer N3 --reg 1e-1 --max_epochs 200 --valid 5 -train -id 0 -save

# %%
# !python learn.py --dataset Atomic --model BiQUE --rank 128 \
#         --optimizer Adagrad --learning_rate 1e-1 --batch_size 2000 \
#         --regularizer N3 --reg 5e-3 --max_epochs 200 --valid 5 -train -id 0 -save
