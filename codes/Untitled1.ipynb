# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# !python learn.py --dataset WN18RR --model BiQUE --rank 500 \
        --optimizer Adagrad --learning_rate 1e-1 --batch_size 300 \
        --regularizer N3 --reg 0.0 --max_epochs 100 --valid 5 -train -id 0 -save -weight #1.5e-1
